# %%
import os
import spectral

import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# %%
def split_and_display_image(image_path):
    # 이미지 열기
    img = Image.open(image_path)

    # 원본 이미지 크기
    width, height = img.size

    # 3x2로 나누기 위해 각 조각의 크기 계산
    piece_width = (width // 3) * 0.9
    piece_height = height // 2

    # 잘라낸 이미지 저장할 리스트
    pieces = []

    # 이미지를 3x2로 나누기
    for row in range(2):  # 2행
        for col in range(3):  # 3열
            left = col * piece_width
            upper = row * piece_height
            right = (col + 1) * piece_width
            lower = (row + 1) * piece_height

            # 이미지 조각 잘라내기
            piece = img.crop((left, upper, right, lower))
            pieces.append(piece)

    # 조각들을 matplotlib으로 출력
    fig, axes = plt.subplots(2, 3, figsize=(9, 6))  # 2행 3열 서브플롯
    for i, ax in enumerate(axes.flat):
        ax.imshow(pieces[i])
        ax.axis('off')  # 축 표시 제거

    plt.tight_layout()
    plt.show()

# %%
def display_hyperspectral_band(hdr_path, raw_path, wavelength):
    # Hyperspectral 이미지를 읽기
    img = spectral.open_image(hdr_path)

    # 특정 파장에 가까운 밴드 찾기
    wavelengths = img.metadata['wavelength']
    wavelengths = [float(w) for w in wavelengths]

    # 특정 파장에 가장 가까운 인덱스 찾기
    band_index = min(range(len(wavelengths)), key=lambda i: abs(wavelengths[i] - wavelength))

    # 해당 밴드 데이터 추출
    band_data = img.read_band(band_index)

    # 이미지 출력
    plt.figure(figsize=(8, 6))
    plt.imshow(band_data, cmap='gray')
    plt.title(f'Band at {wavelengths[band_index]} nm')
    plt.colorbar(label='Pixel Intensity')
    plt.axis('off')
    plt.show()

    print(img.shape)

# %%
def split_hyperspectral_cube(hdr_path, raw_path, output_dir):
    print(hdr_path)
    print(raw_path)
    # Hyperspectral 이미지를 읽기
    img = spectral.open_image(hdr_path)
    cube = img.load()

    # 원본 데이터 크기
    height, width, bands = cube.shape

    # 3x2로 나누기 위해 각 조각의 크기 계산
    piece_width = (width // 2)
    piece_height = height // 2

    # 출력 디렉토리 생성
    os.makedirs(output_dir, exist_ok=True)

    # 6개의 조각으로 분할하여 저장
    cnt = 1
    for row in range(2):
        for col in range(2):
            # 파일명 생성
            file_name = (hdr_path.split("/")[-1])[:-4]

            # 조각의 범위 계산
            start_row = int(row * piece_height)
            end_row = int((row + 1) * piece_height)
            start_col = int(col * piece_width)
            end_col = int((col + 1) * piece_width)

            # 조각 데이터 추출
            piece_cube = cube[start_row:end_row, start_col:end_col, :]

            # HDR 및 RAW 파일 저장
            piece_hdr_path = os.path.join(output_dir, f"{file_name}_{cnt}.hdr")
            piece_raw_path = os.path.join(output_dir, f"{file_name}_{cnt}.raw")
            print(piece_hdr_path)

            # HDR 파일 생성
            metadata = img.metadata.copy()
            metadata['lines'] = piece_cube.shape[0]
            metadata['samples'] = piece_cube.shape[1]
            spectral.envi.save_image(piece_hdr_path, piece_cube, metadata=metadata, interleave='bip', force=True)

            # RAW 파일 저장
            piece_cube.tofile(piece_raw_path)

            # PNG 파일 저장 (100, 150, 200 밴드 활용 RGB 이미지)
            piece_png_path = os.path.join(output_dir, f"{file_name}_{cnt}.png")
            rgb_image = np.stack([piece_cube[:, :, 100].squeeze(), 
                                  piece_cube[:, :, 150].squeeze(), 
                                  piece_cube[:, :, 200].squeeze()], axis=2)
            rgb_image = (rgb_image - np.min(rgb_image)) / (np.max(rgb_image) - np.min(rgb_image)) * 255  # Normalize to [0, 255]
            rgb_image = rgb_image.astype(np.uint8)  # Convert to uint8
            plt.imsave(piece_png_path, rgb_image)

            # plt.imshow(piece_cube[:, :, 100])
            # plt.show()
            # plt.imshow(piece_cube[:, :, 150])
            # plt.show()
            # plt.imshow(piece_cube[:, :, 200])
            # plt.show()
            # plt.imshow(rgb_image)
            # plt.show()
            
            # .img 파일 삭제
            piece_img_path = piece_hdr_path.replace('.hdr', '.img')
            if os.path.exists(piece_img_path):
                os.remove(piece_img_path)
            cnt += 1

    print(f"Split and saved 6 pieces to directory: {output_dir}")

# %%
# 데이터 폴더 전체를 순회하며 HDR 파일을 처리
input_dir = r"C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data"
output_dir = r"C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited"

# HDR 파일 리스트 생성
hdr_files = []
for f in os.listdir(input_dir):
    if f.endswith('.hdr'):
        full_path = f"{input_dir}/{f}"
        hdr_files.append(full_path)

# HDR 파일 순회 처리
for hdr_path in hdr_files:
    raw_path = hdr_path.replace('.hdr', '.raw')  # 대응되는 RAW 파일 경로

    # 분할 후 저장해야 할 경우 아래 한 줄 주석 해제
    split_hyperspectral_cube(hdr_path, raw_path, output_dir)
# Out:
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906124242_0008.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906124242_0008.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906124242_0008_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906124242_0008_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906124242_0008_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906124242_0008_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906124825_0009.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906124825_0009.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906124825_0009_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906124825_0009_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906124825_0009_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906124825_0009_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906125105_0010.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906125105_0010.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125105_0010_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125105_0010_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125105_0010_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125105_0010_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906125255_0011.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906125255_0011.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125255_0011_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125255_0011_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125255_0011_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125255_0011_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906125401_0012.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906125401_0012.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125401_0012_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125401_0012_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125401_0012_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125401_0012_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906125508_0013.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906125508_0013.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125508_0013_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125508_0013_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125508_0013_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125508_0013_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906125626_0014.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906125626_0014.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125626_0014_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125626_0014_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125626_0014_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906125626_0014_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135133_0015.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135133_0015.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135133_0015_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135133_0015_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135133_0015_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135133_0015_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135242_0016.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135242_0016.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135242_0016_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135242_0016_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135242_0016_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135242_0016_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135321_0017.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135321_0017.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135321_0017_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135321_0017_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135321_0017_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135321_0017_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135422_0018.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135422_0018.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135422_0018_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135422_0018_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135422_0018_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135422_0018_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135449_0019.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135449_0019.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135449_0019_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135449_0019_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135449_0019_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135449_0019_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135515_0020.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135515_0020.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135515_0020_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135515_0020_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135515_0020_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135515_0020_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135618_0021.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135618_0021.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135618_0021_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135618_0021_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135618_0021_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135618_0021_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135650_0022.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135650_0022.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135650_0022_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135650_0022_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135650_0022_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135650_0022_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135716_0023.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135716_0023.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135716_0023_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135716_0023_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135716_0023_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135716_0023_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135853_0024.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135853_0024.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135853_0024_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135853_0024_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135853_0024_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135853_0024_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135920_0025.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135920_0025.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135920_0025_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135920_0025_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135920_0025_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135920_0025_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135947_0026.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906135947_0026.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135947_0026_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135947_0026_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135947_0026_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906135947_0026_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140125_0028.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140125_0028.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140125_0028_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140125_0028_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140125_0028_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140125_0028_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140153_0029.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140153_0029.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140153_0029_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140153_0029_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140153_0029_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140153_0029_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140300_0030.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140300_0030.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140300_0030_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140300_0030_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140300_0030_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140300_0030_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140422_0031.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140422_0031.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140422_0031_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140422_0031_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140422_0031_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140422_0031_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140449_0032.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140449_0032.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140449_0032_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140449_0032_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140449_0032_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140449_0032_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140516_0033.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140516_0033.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140516_0033_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140516_0033_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140516_0033_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140516_0033_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140659_0034.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140659_0034.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140659_0034_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140659_0034_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140659_0034_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140659_0034_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140725_0035.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140725_0035.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140725_0035_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140725_0035_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140725_0035_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140725_0035_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140749_0036.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\data/Hsi20240906140749_0036.raw
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140749_0036_1.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140749_0036_2.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140749_0036_3.hdr
# C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited\Hsi20240906140749_0036_4.hdr
# Split and saved 6 pieces to directory: C:\Users\Jaehyuk\Desktop\2024 자체 구축 데이터셋\토마토\splited

# %%
# # hdr 및 raw 파일 경로와 원하는 파장 입력
# hdr_path = r"C:/Users/Jaehyuk/Desktop/2024 자체 구축 데이터셋/사과/241205 사과 당도/data/Hsi20241206162937_0276.hdr"  # HDR 파일 경로
# raw_path = r"C:/Users/Jaehyuk/Desktop/2024 자체 구축 데이터셋/사과/241205 사과 당도/data/Hsi20241206162937_0276.raw"  # RAW 파일 경로
# wavelength = 1300  # 원하는 파장 (nm)

# display_hyperspectral_band(hdr_path, raw_path, wavelength)
